# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Q9_a.csv")

# %%
df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %% [markdown]
# To do : Calculate Skewness, Kurtosis & draw inferences of Cars, speed and distance

# %%
df.rename(columns = {"Index":"Cars", "speed":"speed", "dist":"distance"},inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Cars      50 non-null     int64
#  1   speed     50 non-null     int64
#  2   distance  50 non-null     int64
# dtypes: int64(3)
# memory usage: 1.3 KB

# %%
Kurtosis = df.kurt(axis = 0)

# %%
Kurtosis
# Out:
# Cars       -1.200000
# speed      -0.508994
# distance    0.405053
# dtype: float64

# %%
Skewness = df.skew(axis = 0)

# %%
Skewness
# Out:
# Cars        0.000000
# speed      -0.117510
# distance    0.806895
# dtype: float64

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.hist(df['speed'])#, bins=10, color='skyblue', edgecolor='black'
plt.xlabel('Speed')
plt.ylabel('Frequency')
plt.title('Distribution of Speed')

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.hist(df['distance'])# , bins=10, color='lightgreen', edgecolor='black'
plt.xlabel('Distance')
plt.ylabel('Frequency')
plt.title('Distribution of Distance')
# Out:
# Text(0.5, 1.0, 'Distribution of Distance')

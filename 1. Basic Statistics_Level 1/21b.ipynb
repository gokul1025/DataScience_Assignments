# %% [markdown]
# Check Whether the Adipose Tissue (AT) and Waist Circumference(Waist)  from wc-at data set  follows Normal Distribution
#        Dataset: wc-at.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

# %%
q21b = pd.read_csv("wc-at.csv")
q21b
# Out:
#       Waist      AT
# 0     74.75   25.72
# 1     72.60   25.89
# 2     81.80   42.60
# 3     83.95   42.80
# 4     74.65   29.84
# ..      ...     ...
# 104  100.10  124.00
# 105   93.30   62.20
# 106  101.80  133.00
# 107  107.90  208.00
# 108  108.50  208.00
#
# [109 rows x 2 columns]

# %%
plt.hist(q21b['Waist'], edgecolor= 'yellow')
plt.show()

# %%
plt.boxplot(x = 'Waist', data= q21b)
plt.title("Waist")
#plt.savefig('Waist.png')
plt.show()

# %%
sn.distplot(q21b['Waist'], 
             bins=10,
            kde = True
            )
plt.show()
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_16668\3338796176.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(q21b['Waist'],

# %%
import statsmodels.api as sm
sm.qqplot(q21b['Waist'])
plt.show()

# %%
import scipy.stats as stats
stats.probplot(q21b['Waist'], dist = 'norm', plot = plt)
plt.xlabel('Waist')
plt.savefig('Waist.png')
plt.show()

# %%
sn.distplot(q21b['AT'], bins =10, kde=True)
plt.show()
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_16668\3899624206.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sn.distplot(q21b['AT'], bins =10, kde=True)

# %%
sm.qqplot(q21b['AT'])
plt.show()

# %%
stats.probplot(q21b['AT'], dist = 'norm', plot = plt)
plt.xlabel('AT')
plt.savefig('AT.png')
plt.show()

# %% [markdown]
# To find: Mean, Median, Mode, Variance, Standard Deviation, Range and draw inferences

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Q7.csv")

# %%
df
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  32 non-null     object
#  1   Points      32 non-null     float64
#  2   Score       32 non-null     float64
#  3   Weigh       32 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 1.1+ KB

# %%
data = df[['Points', 'Score', 'Weigh']]

# %%
data
# Out:
#     Points  Score  Weigh
# 0     3.90  2.620  16.46
# 1     3.90  2.875  17.02
# 2     3.85  2.320  18.61
# 3     3.08  3.215  19.44
# 4     3.15  3.440  17.02
# 5     2.76  3.460  20.22
# 6     3.21  3.570  15.84
# 7     3.69  3.190  20.00
# 8     3.92  3.150  22.90
# 9     3.92  3.440  18.30
# 10    3.92  3.440  18.90
# 11    3.07  4.070  17.40
# 12    3.07  3.730  17.60
# 13    3.07  3.780  18.00
# 14    2.93  5.250  17.98
# 15    3.00  5.424  17.82
# 16    3.23  5.345  17.42
# 17    4.08  2.200  19.47
# 18    4.93  1.615  18.52
# 19    4.22  1.835  19.90
# 20    3.70  2.465  20.01
# 21    2.76  3.520  16.87
# 22    3.15  3.435  17.30
# 23    3.73  3.840  15.41
# 24    3.08  3.845  17.05
# 25    4.08  1.935  18.90
# 26    4.43  2.140  16.70
# 27    3.77  1.513  16.90
# 28    4.22  3.170  14.50
# 29    3.62  2.770  15.50
# 30    3.54  3.570  14.60
# 31    4.11  2.780  18.60

# %%
data.head()
# Out:
#    Points  Score  Weigh
# 0    3.90  2.620  16.46
# 1    3.90  2.875  17.02
# 2    3.85  2.320  18.61
# 3    3.08  3.215  19.44
# 4    3.15  3.440  17.02

# %%
data.tail()
# Out:
#     Points  Score  Weigh
# 27    3.77  1.513   16.9
# 28    4.22  3.170   14.5
# 29    3.62  2.770   15.5
# 30    3.54  3.570   14.6
# 31    4.11  2.780   18.6

# %%
data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000

# %%
data.max()
# Out:
# Points     4.930
# Score      5.424
# Weigh     22.900
# dtype: float64

# %%
data.min()
# Out:
# Points     2.760
# Score      1.513
# Weigh     14.500
# dtype: float64

# %%
data.mean()
# Out:
# Points     3.596563
# Score      3.217250
# Weigh     17.848750
# dtype: float64

# %%
data.mode()
# Out:
#    Points  Score  Weigh
# 0    3.07   3.44  17.02
# 1    3.92    NaN  18.90

# %%
data.median()
# Out:
# Points     3.695
# Score      3.325
# Weigh     17.710
# dtype: float64

# %%
data.std()
# Out:
# Points    0.534679
# Score     0.978457
# Weigh     1.786943
# dtype: float64

# %%
range = data.max() - data.min()

# %%
range
# Out:
# Points    2.170
# Score     3.911
# Weigh     8.400
# dtype: float64

# %%
data.var()
# Out:
# Points    0.285881
# Score     0.957379
# Weigh     3.193166
# dtype: float64

# %%
#data = df[['Points', 'Score', 'Weigh']]

# %%
plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.hist(df['Score'])#, bins=10, color='skyblue', edgecolor='black'
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Distribution of Score')
plt.savefig("squares.png")

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.hist(df['Weigh'])# , bins=10, color='lightgreen', edgecolor='black'
plt.xlabel('Weigh')
plt.ylabel('Frequency')
plt.title('Distribution of Weigh')
plt.savefig("squares1.png")

plt.figure(figsize=(10, 5))
plt.subplot(1,2,1)
plt.hist(df['Points'])# , bins=10, color='lightyellow', edgecolor='black'
plt.xlabel('Points')
plt.ylabel('Frequency')
plt.title('Distribution of Points')

plt.savefig("squares2.png")

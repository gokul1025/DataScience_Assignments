# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV, KFold
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.optimizers import Adam
from keras.layers import Dropout

# %%
df=pd.read_csv("gas_turbines.csv")
df=df.iloc[:,[7,0,1,2]]
df.shape
# Out:
# (15039, 4)

# %%
df.describe()
# Out:
#                 TEY            AT           AP            AH
# count  15039.000000  15039.000000  15039.00000  15039.000000
# mean     134.188464     17.764381   1013.19924     79.124174
# std       15.829717      7.574323      6.41076     13.793439
# min      100.170000      0.522300    985.85000     30.344000
# 25%      127.985000     11.408000   1008.90000     69.750000
# 50%      133.780000     18.186000   1012.80000     82.266000
# 75%      140.895000     23.862500   1016.90000     90.043500
# max      174.610000     34.929000   1034.20000    100.200000

# %%
df.isnull().sum()
# Out:
# TEY    0
# AT     0
# AP     0
# AH     0
# dtype: int64

# %%
x=df.iloc[:,1:5]
y=df.iloc[:,0]

# %%
x
# Out:
#            AT      AP      AH
# 0      6.8594  1007.9  96.799
# 1      6.7850  1008.4  97.118
# 2      6.8977  1008.8  95.939
# 3      7.0569  1009.2  95.249
# 4      7.3978  1009.7  95.150
# ...       ...     ...     ...
# 15034  9.0301  1005.6  98.460
# 15035  7.8879  1005.9  99.093
# 15036  7.2647  1006.3  99.496
# 15037  7.0060  1006.8  99.008
# 15038  6.9279  1007.2  97.533
#
# [15039 rows x 3 columns]

# %%
y
# Out:
# 0        114.70
# 1        114.72
# 2        114.71
# 3        114.72
# 4        114.72
#           ...
# 15034    111.61
# 15035    111.78
# 15036    110.19
# 15037    110.74
# 15038    111.58
# Name: TEY, Length: 15039, dtype: float64

# %%
seed = 7
np.random.seed(seed)
model = Sequential()
model.add(Dense(12, input_dim=3,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(8,  kernel_initializer='uniform', activation='relu'))
model.add(Dense(1,  kernel_initializer='uniform', activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history= model.fit(x, y,validation_split=0.33, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3430605.0000 - accuracy: 0.0000e+00 - val_loss: -13294442.0000 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 1008/1008 [==============================] - 2s 1ms/step - loss: -46082976.0000 - accuracy: 0.0000e+00 - val_loss: -90435168.0000 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -170561136.0000 - accuracy: 0.0000e+00 - val_loss: -259223680.0000 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -396465632.0000 - accuracy: 0.0000e+00 - val_loss: -533388992.0000 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -736141504.0000 - accuracy: 0.0000e+00 - val_loss: -924231424.0000 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 1008/1008 [==============================] - 1s 1ms/step - loss: -1201166592.0000 - accuracy: 0.0000e+00 - val_loss: -1442983936.0000 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 1008/1008 [==============================] - 2s 1ms/step - loss: -1803604480.0000 - accuracy: 0.0000e+00 - val_loss: -2101942912.0000 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -2555387904.0000 - accuracy: 0.0000e+00 - val_loss: -2912049920.0000 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 1008/1008 [==============================] - 2s 2ms/step - loss: -3468717056.0000 - accuracy: 0.0000e+00 - val_loss: -3886371584.0000 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 1008/1008 [==============================] - 1s 1ms/step - loss: -
150
# 1008/1008 [==============================] - 1s 1ms/step - loss: -6721074888704.0000 - accuracy: 0.0000e+00 - val_loss: -6622725799936.0000 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 1008/1008 [==============================] - 1s 1ms/step - loss: -6854224642048.0000 - accuracy: 0.0000e+00 - val_loss: -6753483227136.0000 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 1008/1008 [==============================] - 1s 1ms/step - loss: -6989201539072.0000 - accuracy: 0.0000e+00 - val_loss: -6886096633856.0000 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 1008/1008 [==============================] - 2s 1ms/step - loss: -7125903343616.0000 - accuracy: 0.0000e+00 - val_loss: -7020276613120.0000 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 1008/1008 [==============================] - 1s 1ms/step - loss: -7264323239936.0000 - accuracy: 0.0000e+00 - val_loss: -7156203520000.0000 - val_accuracy: 0.0000e+00

# %%
scores = model.evaluate(x, y)
print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 470/470 [==============================] - 1s 1ms/step - loss: -7275465408512.0000 - accuracy: 0.0000e+00
# accuracy: 0.00%

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
a = StandardScaler()
a.fit(x)
X_standardized = a.transform(x)
pd.DataFrame(X_standardized).describe()
# Out:
#                   0             1             2
# count  1.503900e+04  1.503900e+04  1.503900e+04
# mean   4.913654e-16 -1.875504e-14  2.570219e-16
# std    1.000033e+00  1.000033e+00  1.000033e+00
# min   -2.276462e+00 -4.266288e+00 -3.536594e+00
# 25%   -8.392292e-01 -6.706510e-01 -6.796337e-01
# 50%    5.566605e-02 -6.227861e-02  2.277844e-01
# 75%    8.051309e-01  5.772924e-01  7.916582e-01
# max    2.266234e+00  3.275970e+00  1.528011e+00

# %%
def create_model():
    model = Sequential()
    model.add(Dense(12, input_dim=3, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(8, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))\
    
    adam=Adam(lr=0.01)
    model.compile(loss='binary_crossentropy', optimizer=adam, metrics=['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0)
batch_size = [10,20,40]
epochs = [10,50,100]
param_grid = dict(batch_size = batch_size,epochs = epochs)
grid = GridSearchCV(estimator = model,param_grid = param_grid,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_4268\73594983.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  12.1s
# [CV 2/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  12.4s
# [CV 3/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  12.7s
# [CV 4/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  12.8s
# [CV 5/5; 1/9] START batch_size=10, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .....batch_size=10, epochs=10;, score=0.000 total time=  12.3s
# [CV 1/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time=  57.6s
# [CV 2/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time=  57.1s
# [CV 3/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time=  56.7s
# [CV 4/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time=  58.2s
# [CV 5/5; 2/9] START batch_size=10, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .....batch_size=10, epochs=50;, score=0.000 total time=  58.4s
# [CV 1/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 1.9min
# [CV 2/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 2.0min
# [CV 3/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 1.9min
# [CV 4/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 1.9min
# [CV 5/5; 3/9] START batch_size=10, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END ....batch_size=10, epochs=100;, score=0.000 total time= 1.9min
# [CV 1/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   6.7s
# [CV 2/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   6.7s
# [CV 3/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   7.0s
# [CV 4/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   6.8s
# [CV 5/5; 4/9] START batch_size=20, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .....batch_size=20, epochs=10;, score=0.000 total time=   6.6s
# [CV 1/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  29.8s
# [CV 2/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  29.1s
# [CV 3/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  29.2s
# [CV 4/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  29.2s
# [CV 5/5; 5/9] START batch_size=20, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .....batch_size=20, epochs=50;, score=0.000 total time=  29.1s
# [CV 1/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.0min
# [CV 2/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.0min
# [CV 3/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.0min
# [CV 4/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time= 1.0min
# [CV 5/5; 6/9] START batch_size=20, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END ....batch_size=20, epochs=100;, score=0.000 total time=  59.8s
# [CV 1/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   4.0s
# [CV 2/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   3.8s
# [CV 3/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   3.8s
# [CV 4/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   4.1s
# [CV 5/5; 7/9] START batch_size=40, epochs=10....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END .....batch_size=40, epochs=10;, score=0.000 total time=   3.9s
# [CV 1/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  15.7s
# [CV 2/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  15.9s
# [CV 3/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  15.5s
# [CV 4/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  15.0s
# [CV 5/5; 8/9] START batch_size=40, epochs=50....................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END .....batch_size=40, epochs=50;, score=0.000 total time=  14.8s
# [CV 1/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  31.0s
# [CV 2/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  32.0s
# [CV 3/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  30.8s
# [CV 4/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  30.9s
# [CV 5/5; 9/9] START batch_size=40, epochs=100...................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END ....batch_size=40, epochs=100;, score=0.000 total time=  29.5s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'batch_size': 10, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 10, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 20, 'epochs': 100}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 10}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 50}
# 0.0,0.0 with: {'batch_size': 40, 'epochs': 100}

# %%
def create_model(learning_rate,dropout_rate):
    model = Sequential()
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(4,input_dim = 3,kernel_initializer = 'normal',activation = 'relu'))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = learning_rate)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)


learning_rate = [0.001,0.01,0.1]
dropout_rate = [0.0,0.1,0.2]


param_grids = dict(learning_rate = learning_rate,dropout_rate = dropout_rate)

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_4268\2472349717.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   4.0s
# [CV 2/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   3.9s
# [CV 3/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   3.9s
# [CV 4/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   3.8s
# [CV 5/5; 1/9] START dropout_rate=0.0, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END dropout_rate=0.0, learning_rate=0.001;, score=0.000 total time=   3.9s
# [CV 1/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   3.9s
# [CV 2/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   4.0s
# [CV 3/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   4.0s
# [CV 4/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   4.4s
# [CV 5/5; 2/9] START dropout_rate=0.0, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END dropout_rate=0.0, learning_rate=0.01;, score=0.000 total time=   3.8s
# [CV 1/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   3.8s
# [CV 2/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   3.9s
# [CV 3/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   3.8s
# [CV 4/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   3.9s
# [CV 5/5; 3/9] START dropout_rate=0.0, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END dropout_rate=0.0, learning_rate=0.1;, score=0.000 total time=   4.0s
# [CV 1/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   4.2s
# [CV 2/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   4.1s
# [CV 3/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   4.1s
# [CV 4/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   4.1s
# [CV 5/5; 4/9] START dropout_rate=0.1, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END dropout_rate=0.1, learning_rate=0.001;, score=0.000 total time=   4.0s
# [CV 1/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   3.9s
# [CV 2/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   4.0s
# [CV 3/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   4.7s
# [CV 4/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   4.4s
# [CV 5/5; 5/9] START dropout_rate=0.1, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END dropout_rate=0.1, learning_rate=0.01;, score=0.000 total time=   4.4s
# [CV 1/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=   4.5s
# [CV 2/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=   4.4s
# [CV 3/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=   4.3s
# [CV 4/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=   4.3s
# [CV 5/5; 6/9] START dropout_rate=0.1, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END dropout_rate=0.1, learning_rate=0.1;, score=0.000 total time=   4.1s
# [CV 1/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   4.2s
# [CV 2/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   4.2s
# [CV 3/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   4.2s
# [CV 4/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   4.3s
# [CV 5/5; 7/9] START dropout_rate=0.2, learning_rate=0.001.......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END dropout_rate=0.2, learning_rate=0.001;, score=0.000 total time=   4.2s
# [CV 1/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   4.1s
# [CV 2/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   4.1s
# [CV 3/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   4.6s
# [CV 4/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   4.4s
# [CV 5/5; 8/9] START dropout_rate=0.2, learning_rate=0.01........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END dropout_rate=0.2, learning_rate=0.01;, score=0.000 total time=   4.2s
# [CV 1/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=   4.4s
# [CV 2/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=   4.2s
# [CV 3/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=   4.1s
# [CV 4/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=   4.1s
# [CV 5/5; 9/9] START dropout_rate=0.2, learning_rate=0.1.........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/9] END dropout_rate=0.2, learning_rate=0.1;, score=0.000 total time=   4.2s

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.0, 'learning_rate': 0.1}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.1, 'learning_rate': 0.1}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.001}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.01}
# 0.0,0.0 with: {'dropout_rate': 0.2, 'learning_rate': 0.1}

# %%
def create_model(activation_function,init):
    model = Sequential()
    model.add(Dense(8,input_dim = 3,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(4,input_dim = 3,kernel_initializer = init,activation = activation_function))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

activation_function = ['softmax','relu','tanh','linear']
init = ['uniform','normal','zero']

param_grids = dict(activation_function = activation_function,init = init)

grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_4268\2150382326.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   4.4s
# [CV 2/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   4.3s
# [CV 3/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   4.3s
# [CV 4/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   4.3s
# [CV 5/5; 1/12] START activation_function=softmax, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/12] END activation_function=softmax, init=uniform;, score=0.000 total time=   4.2s
# [CV 1/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   4.6s
# [CV 2/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   4.3s
# [CV 3/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   4.4s
# [CV 4/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   4.4s
# [CV 5/5; 2/12] START activation_function=softmax, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/12] END activation_function=softmax, init=normal;, score=0.000 total time=   4.3s
# [CV 1/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   4.2s
# [CV 2/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   6.3s
# [CV 3/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   5.7s
# [CV 4/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   4.5s
# [CV 5/5; 3/12] START activation_function=softmax, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/12] END activation_function=softmax, init=zero;, score=0.000 total time=   4.3s
# [CV 1/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   4.2s
# [CV 2/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   4.3s
# [CV 3/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   4.5s
# [CV 4/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   4.3s
# [CV 5/5; 4/12] START activation_function=relu, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/12] END activation_function=relu, init=uniform;, score=0.000 total time=   4.8s
# [CV 1/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   4.5s
# [CV 2/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   4.4s
# [CV 3/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   4.5s
# [CV 4/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   4.3s
# [CV 5/5; 5/12] START activation_function=relu, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/12] END activation_function=relu, init=normal;, score=0.000 total time=   4.4s
# [CV 1/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   4.4s
# [CV 2/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   4.2s
# [CV 3/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   4.3s
# [CV 4/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   4.3s
# [CV 5/5; 6/12] START activation_function=relu, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/12] END activation_function=relu, init=zero;, score=0.000 total time=   4.2s
# [CV 1/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   4.2s
# [CV 2/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   4.2s
# [CV 3/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   4.0s
# [CV 4/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   4.2s
# [CV 5/5; 7/12] START activation_function=tanh, init=uniform.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/12] END activation_function=tanh, init=uniform;, score=0.000 total time=   4.6s
# [CV 1/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   4.3s
# [CV 2/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   4.4s
# [CV 3/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   4.5s
# [CV 4/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   4.8s
# [CV 5/5; 8/12] START activation_function=tanh, init=normal......................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/12] END activation_function=tanh, init=normal;, score=0.000 total time=   4.7s
# [CV 1/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   4.3s
# [CV 2/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   4.1s
# [CV 3/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   4.3s
# [CV 4/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   4.4s
# [CV 5/5; 9/12] START activation_function=tanh, init=zero........................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 9/12] END activation_function=tanh, init=zero;, score=0.000 total time=   4.3s
# [CV 1/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   4.2s
# [CV 2/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   4.2s
# [CV 3/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   4.1s
# [CV 4/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   4.5s
# [CV 5/5; 10/12] START activation_function=linear, init=uniform..................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 10/12] END activation_function=linear, init=uniform;, score=0.000 total time=   4.3s
# [CV 1/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   4.2s
# [CV 2/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   4.2s
# [CV 3/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   4.3s
# [CV 4/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   4.3s
# [CV 5/5; 11/12] START activation_function=linear, init=normal...................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 11/12] END activation_function=linear, init=normal;, score=0.000 total time=   4.3s
# [CV 1/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   4.2s
# [CV 2/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   4.1s
# [CV 3/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   4.1s
# [CV 4/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   4.1s
# [CV 5/5; 12/12] START activation_function=linear, init=zero.....................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 12/12] END activation_function=linear, init=zero;, score=0.000 total time=   4.2s

# %%
def create_model(neuron1,neuron2):
    model = Sequential()
    model.add(Dense(neuron1,input_dim = 3,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(neuron2,input_dim = neuron1,kernel_initializer = 'uniform',activation = 'tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'sigmoid'))
    
    adam = Adam(lr = 0.001)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)

neuron1 = [4,8,16]
neuron2 = [2,4,8]


param_grids = dict(neuron1 = neuron1,neuron2 = neuron2)


grid = GridSearchCV(estimator = model,param_grid = param_grids,cv = KFold(),verbose = 10)
grid_result = grid.fit(X_standardized,y)
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_4268\1328446193.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 10)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# [CV 1/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   4.2s
# [CV 2/5; 1/9] START neuron1=4, neuron2=2........................................
# [CV 2/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   4.2s
# [CV 3/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   4.6s
# [CV 4/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   4.3s
# [CV 5/5; 1/9] START neuron1=4, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 1/9] END .........neuron1=4, neuron2=2;, score=0.000 total time=   4.2s
# [CV 1/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   4.4s
# [CV 2/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   4.3s
# [CV 3/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   4.2s
# [CV 4/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   4.2s
# [CV 5/5; 2/9] START neuron1=4, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 2/9] END .........neuron1=4, neuron2=4;, score=0.000 total time=   4.3s
# [CV 1/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   4.2s
# [CV 2/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   4.3s
# [CV 3/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   4.2s
# [CV 4/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   4.1s
# [CV 5/5; 3/9] START neuron1=4, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 3/9] END .........neuron1=4, neuron2=8;, score=0.000 total time=   4.1s
# [CV 1/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   4.1s
# [CV 2/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   4.5s
# [CV 3/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   4.4s
# [CV 4/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   4.5s
# [CV 5/5; 4/9] START neuron1=8, neuron2=2........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 4/9] END .........neuron1=8, neuron2=2;, score=0.000 total time=   4.2s
# [CV 1/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   4.2s
# [CV 2/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   4.1s
# [CV 3/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   4.2s
# [CV 4/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   4.3s
# [CV 5/5; 5/9] START neuron1=8, neuron2=4........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 5/9] END .........neuron1=8, neuron2=4;, score=0.000 total time=   4.3s
# [CV 1/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   4.2s
# [CV 2/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   4.1s
# [CV 3/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   4.2s
# [CV 4/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   4.2s
# [CV 5/5; 6/9] START neuron1=8, neuron2=8........................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 6/9] END .........neuron1=8, neuron2=8;, score=0.000 total time=   4.1s
# [CV 1/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   4.6s
# [CV 2/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   4.2s
# [CV 3/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   4.3s
# [CV 4/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   4.3s
# [CV 5/5; 7/9] START neuron1=16, neuron2=2.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 7/9] END ........neuron1=16, neuron2=2;, score=0.000 total time=   4.4s
# [CV 1/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   4.4s
# [CV 2/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   4.4s
# [CV 3/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   4.3s
# [CV 4/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   4.4s
# [CV 5/5; 8/9] START neuron1=16, neuron2=4.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 5/5; 8/9] END ........neuron1=16, neuron2=4;, score=0.000 total time=   4.3s
# [CV 1/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 1/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   4.3s
# [CV 2/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 2/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   4.3s
# [CV 3/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 3/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   4.4s
# [CV 4/5; 9/9] START neuron1=16, neuron2=8.......................................
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# [CV 4/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   4.2s
# [CV 5/5; 9/9] START neuron1=16, neuron2=8.......................................
# [CV 5/5; 9/9] END ........neuron1=16, neuron2=8;, score=0.000 total time=   4.1s
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
print('Best : {}, using {}'.format(grid_result.best_score_,grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
  print('{},{} with: {}'.format(mean, stdev, param))
# Out:
# Best : 0.0, using {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 4, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 8, 'neuron2': 8}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 2}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 4}
# 0.0,0.0 with: {'neuron1': 16, 'neuron2': 8}

# %%
from sklearn.metrics import classification_report, accuracy_score
def create_model():
    model = Sequential()
    model.add(Dense(16,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(8,input_dim = 3,kernel_initializer = 'normal',activation = 'linear'))
    model.add(Dropout(0.1))
    model.add(Dense(1,activation = 'linear'))
    
    adam = Adam(lr = 0.01) #sgd = SGD(lr=learning_rate, momentum=momentum, decay=decay_rate, nesterov=False)
    model.compile(loss = 'binary_crossentropy',optimizer = adam,metrics = ['accuracy'])
    return model

# %%
model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)


model.fit(X_standardized,y)


y_predict = model.predict(X_standardized)

print(accuracy_score(y_predict.round(),y.round()))
# Out:
# C:\Users\shlok\AppData\Local\Temp\ipykernel_4268\641616389.py:1: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn = create_model,verbose = 0,batch_size = 40,epochs = 100)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 470/470 [==============================] - 0s 810us/step
# 0.00013298756566261055
